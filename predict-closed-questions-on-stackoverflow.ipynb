# %%
# ! pip install -U spacy

# %%
# ! spacy download en_core_web_sm

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import spacy
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 
# Let's covvert words to numbers using TF-IDF 
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.layers import Dense, Flatten, Input
from keras.models import Sequential
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
def remove_num_punc(text):
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    return text.lower()

# %%
def lemmitization(text):
    words = ''
    for word in text:
        words += ' ' + word.lemma_
    return words

# %%
nlp = spacy.load('en_core_web_sm')

# %%
data = pd.read_csv('/kaggle/input/predict-closed-questions-on-stack-overflow/train-sample.csv')

# %%
data.head()
# Out:
#      PostId     PostCreationDate  OwnerUserId    OwnerCreationDate  \
# 0   6046168  05/18/2011 14:14:05       543315  09/17/2010 10:15:06
# 1   4873911  02/02/2011 11:30:10       465076  10/03/2010 09:30:58
# 2   3311559  07/22/2010 17:21:54       406143  07/22/2010 16:58:20
# 3   9990413  04/03/2012 09:18:39       851755  07/19/2011 10:22:40
# 4  10421966  05/02/2012 21:25:01       603588  02/04/2011 18:05:34
#
#    ReputationAtPostCreation  OwnerUndeletedAnswerCountAtPostTime  \
# 0                         1                                    2
# 1                       192                                   24
# 2                         1                                    0
# 3                         4                                    1
# 4                       334                                   14
#
#                                                Title  \
# 0  For Mongodb is it better to reference an objec...
# 1  How to insert schemalocation in a xml document...
# 2                            Too many lookup tables
# 3                    What is this PHP code in VB.net
# 4  Spring-Data mongodb querying multiple classes ...
#
#                                         BodyMarkdown        Tag1  \
# 0  I am building a corpus of indexed sentences in...     mongodb
# 1  i create a xml document with JAXP and search a...         dom
# 2  What are the adverse effects of having too man...  sql-server
# 3  I am looking for the vb.net equivalent of this...         php
# 4  With Spring-Data, you can use the @Document an...     mongodb
#
#               Tag2   Tag3 Tag4 Tag5       PostClosedDate     OpenStatus
# 0              NaN    NaN  NaN  NaN                  NaN           open
# 1              xsd   jaxp  NaN  NaN                  NaN           open
# 2  database-design  enums  NaN  NaN                  NaN           open
# 3           vb.net    NaN  NaN  NaN  04/15/2012 21:12:48  too localized
# 4      spring-data    NaN  NaN  NaN                  NaN           open

# %%
data.shape
# Out:
# (140272, 15)

# %%
data = data.sample(80000, random_state = 234)
data.head()
# Out:
#           PostId     PostCreationDate  OwnerUserId    OwnerCreationDate  \
# 122715   1296097  08/18/2009 19:51:02       135646  07/09/2009 13:13:22
# 29350    9349765  02/19/2012 13:52:14      1216512  02/17/2012 14:57:14
# 6938    10974978  06/11/2012 05:47:32       748164  05/11/2011 07:12:53
# 131897  11364721  07/06/2012 15:00:12       623694  02/18/2011 19:35:31
# 10420   11076945  06/18/2012 04:31:24      1314162  04/05/2012 01:24:25
#
#         ReputationAtPostCreation  OwnerUndeletedAnswerCountAtPostTime  \
# 122715                       146                                   13
# 29350                          1                                    0
# 6938                          44                                    1
# 131897                       677                                   32
# 10420                          1                                    0
#
#                                                   Title  \
# 122715  How to serialize Color property as ARGB values?
# 29350                       Sending large files in java
# 6938       How to Create personal online radio station?
# 131897         how to name my android software legally?
# 10420                     Broke Emacs 24 on Lion 10.7.4
#
#                                              BodyMarkdown        Tag1  \
# 122715  I'm working with Windows Forms designer. It se...    winforms
# 29350   How to send large files (2-3 GB) over the netw...  networking
# 6938    I want to create my own radio station, that is...     asp.net
# 131897  Im new to android programming and i found a pr...     android
# 10420   I just managed to break my beloved Emacs on Li...       emacs
#
#                          Tag2         Tag3     Tag4           Tag5  \
# 122715  windows-form-designer       colors      rgb  serialization
# 29350                     NaN          NaN      NaN            NaN
# 6938                      NaN          NaN      NaN            NaN
# 131897         android-market  google-play      NaN            NaN
# 10420                osx-lion     macports  ncurses            NaN
#
#              PostClosedDate           OpenStatus
# 122715                  NaN                 open
# 29350   02/20/2012 14:17:34  not a real question
# 6938    06/11/2012 07:35:28            off topic
# 131897  07/06/2012 15:54:05            off topic
# 10420   06/25/2012 15:57:29            off topic

# %%
data.isnull().sum()
# Out:
# PostId                                     0
# PostCreationDate                           0
# OwnerUserId                                0
# OwnerCreationDate                          0
# ReputationAtPostCreation                   0
# OwnerUndeletedAnswerCountAtPostTime        0
# Title                                      0
# BodyMarkdown                               0
# Tag1                                       6
# Tag2                                   15642
# Tag3                                   36753
# Tag4                                   57231
# Tag5                                   71055
# PostClosedDate                         40024
# OpenStatus                                 0
# dtype: int64

# %%
data = data[['Title', 'BodyMarkdown', 'OpenStatus']]

# %%
data.head()
# Out:
#                                                   Title  \
# 122715  How to serialize Color property as ARGB values?
# 29350                       Sending large files in java
# 6938       How to Create personal online radio station?
# 131897         how to name my android software legally?
# 10420                     Broke Emacs 24 on Lion 10.7.4
#
#                                              BodyMarkdown           OpenStatus
# 122715  I'm working with Windows Forms designer. It se...                 open
# 29350   How to send large files (2-3 GB) over the netw...  not a real question
# 6938    I want to create my own radio station, that is...            off topic
# 131897  Im new to android programming and i found a pr...            off topic
# 10420   I just managed to break my beloved Emacs on Li...            off topic

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Title           0
# BodyMarkdown    0
# OpenStatus      0
# dtype: int64

# %%
# data = data[:10000]

# %%
# data['Title'] = data['Title'].apply(lambda x: nlp(x))
# data['BodyMarkdown'] = data['BodyMarkdown'].apply(lambda x: nlp(x))

# %%
data['Title'] = data['Title'].apply(lambda x: remove_num_punc(x))
data['BodyMarkdown'] = data['BodyMarkdown'].apply(lambda x: remove_num_punc(x))

# %%
# data['Title'] = data['Title'].apply(lambda x: lemmitization(x))
# data['BodyMarkdown'] = data['BodyMarkdown'].apply(lambda x: lemmitization(x))

# %%
data.head()
# Out:
#                                                   Title  \
# 122715  how to serialize color property as argb values
# 29350                       sending large files in java
# 6938       how to create personal online radio station
# 131897         how to name my android software legally
# 10420                     broke emacs    on lion
#
#                                              BodyMarkdown           OpenStatus
# 122715  i m working with windows forms designer  it se...                 open
# 29350   how to send large files      gb  over the netw...  not a real question
# 6938    i want to create my own radio station  that is...            off topic
# 131897  im new to android programming and i found a pr...            off topic
# 10420   i just managed to break my beloved emacs on li...            off topic

# %%
encoder = LabelEncoder()
# data['Tag1'] = encoder.fit_transform(data['Tag1'])
data['OpenStatus'] = encoder.fit_transform(data['OpenStatus'])

# %%
data.head()
# Out:
#                                                   Title  \
# 122715  how to serialize color property as argb values
# 29350                       sending large files in java
# 6938       how to create personal online radio station
# 131897         how to name my android software legally
# 10420                     broke emacs    on lion
#
#                                              BodyMarkdown  OpenStatus
# 122715  i m working with windows forms designer  it se...           3
# 29350   how to send large files      gb  over the netw...           0
# 6938    i want to create my own radio station  that is...           2
# 131897  im new to android programming and i found a pr...           2
# 10420   i just managed to break my beloved emacs on li...           2

# %%
target = data['OpenStatus']
data = data.drop(['OpenStatus'], axis=1)

# %%
data.head()
# Out:
#                                                   Title  \
# 122715  how to serialize color property as argb values
# 29350                       sending large files in java
# 6938       how to create personal online radio station
# 131897         how to name my android software legally
# 10420                     broke emacs    on lion
#
#                                              BodyMarkdown
# 122715  i m working with windows forms designer  it se...
# 29350   how to send large files      gb  over the netw...
# 6938    i want to create my own radio station  that is...
# 131897  im new to android programming and i found a pr...
# 10420   i just managed to break my beloved emacs on li...

# %%
data = data['Title'] + ' '+ data['BodyMarkdown']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(data, target, test_size = 0.3, random_state = 42)
data = []

# %%
xtrain.shape
# Out:
# (56000,)

# %%
vectorizer = TfidfVectorizer(max_features = 1000)  # it contains only 10k features (fixed!)

xtrain = vectorizer.fit_transform(xtrain).toarray()  # converting words to numbers for train data 
xtest = vectorizer.transform(xtest).toarray()        # converting words to numbers for test data

# %%
xtrain.shape
# Out:
# (56000, 1000)

# %%
set(ytrain)
# Out:
# {0, 1, 2, 3, 4}

# %%
from sklearn.neural_network import MLPClassifier

mlp_cv=MLPClassifier(early_stopping=True, verbose=2)
mlp_cv.fit(xtrain, ytrain)
# Out:
# Iteration 1, loss = 1.14862808
# Validation score: 0.620893
# Iteration 2, loss = 0.96125810
# Validation score: 0.619643
# Iteration 3, loss = 0.93586758
# Validation score: 0.617143
# Iteration 4, loss = 0.92322745
# Validation score: 0.622143
# Iteration 5, loss = 0.91252599
# Validation score: 0.620536
# Iteration 6, loss = 0.90255585
# Validation score: 0.622500
# Iteration 7, loss = 0.89152095
# Validation score: 0.621071
# Iteration 8, loss = 0.87954500
# Validation score: 0.622321
# Iteration 9, loss = 0.86727904
# Validation score: 0.628036
# Iteration 10, loss = 0.85501732
# Validation score: 0.625357
# Iteration 11, loss = 0.84215464
# Validation score: 0.621071
# Iteration 12, loss = 0.82986132
# Validation score: 0.623036
# Iteration 13, loss = 0.81722133
# Validation score: 0.622321
# Iteration 14, loss = 0.80393377
# Validation score: 0.622500
# Iteration 15, loss = 0.79095773
# Validation score: 0.621429
# Iteration 16, loss = 0.77854277
# Validation score: 0.619821
# Iteration 17, loss = 0.76517680
# Validation score: 0.615714
# Iteration 18, loss = 0.75181827
# Validation score: 0.616964
# Iteration 19, loss = 0.73880412
# Validation score: 0.616964
# Iteration 20, loss = 0.72504821
# Validation score: 0.616607
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(early_stopping=True, verbose=2)

# %%
predicted_mlp = mlp_cv.predict(xtest)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix 

def metrics(predicted): 
    predicted_naive = predicted 
    print('Accuracy Score \n',accuracy_score(predicted_naive, ytest))
    print('Confusion Matrix \n', confusion_matrix(predicted_naive, ytest))
    print('Classification Report \n', classification_report(predicted_naive, ytest))

# %%
metrics(predicted_mlp)
# Out:
# Accuracy Score
#  0.6262083333333334
# Confusion Matrix
#  [[2210  303  354 1123  217]
#  [ 406 1582  448  438   29]
#  [ 298  270 1274  478   61]
#  [2295  521  960 9946  732]
#  [  19    1    2   16   17]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.42      0.53      0.47      4207
#            1       0.59      0.54      0.57      2903
#            2       0.42      0.54      0.47      2381
#            3       0.83      0.69      0.75     14454
#            4       0.02      0.31      0.03        55
#
#     accuracy                           0.63     24000
#    macro avg       0.46      0.52      0.46     24000
# weighted avg       0.69      0.63      0.65     24000

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.6317916666666666

# %%
ann = Sequential()
ann.add(Input(xtrain.shape))
# Add an hidden layer
ann.add(Dense(1024, activation='relu'))
ann.add(Dense(1024, activation='relu'))
ann.add(Dense(512, activation='relu'))
ann.add(Dense(512, activation='relu'))
ann.add(Dense(256, activation='relu'))
ann.add(Dense(128, activation='relu'))
ann.add(Dense(64, activation='relu'))
ann.add(Dense(32, activation='relu'))
ann.add(Dense(16, activation='relu'))
# softmax normalizes it into a probability distribution consisting of
# K probabilities proportional to the exponentials of the input
# Add an output layer
ann.add(Dense(5, activation='softmax'))
# Out:
# 2023-02-10 21:29:14.024846: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.025767: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.026900: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.027652: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.028337: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.029052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.030026: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-10 21:29:14.271613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.272385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.273150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.273862: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.274590: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:14.275271: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:25.035522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:25.036362: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:25.037121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:25.037807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:25.038526: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:25.039498: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12837 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-02-10 21:29:25.042406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-10 21:29:25.043106: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 12837 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 56000, 1024)       1025024
# _________________________________________________________________
# dense_1 (Dense)              (None, 56000, 1024)       1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 56000, 512)        524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 56000, 512)        262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 56000, 256)        131328
# _________________________________________________________________
# dense_5 (Dense)              (None, 56000, 128)        32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 56000, 64)         8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 56000, 32)         2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 56000, 16)         528
# _________________________________________________________________
# dense_9 (Dense)              (None, 56000, 5)          85
# =================================================================
# Total params: 3,037,253
# Trainable params: 3,037,253
# Non-trainable params: 0
# _________________________________________________________________

# %%
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
model_checkpoint = ModelCheckpoint("best_model.h5", save_best_only=True, verbose=1)

# %%
ann.fit(xtrain, ytrain, epochs=50, batch_size=32, validation_data=(xtest, ytest), callbacks=[model_checkpoint])
# Out:
# 2023-02-10 21:29:26.163836: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 1750/1750 [==============================] - 9s 4ms/step - loss: 1.1220 - accuracy: 0.5631 - val_loss: 1.0462 - val_accuracy: 0.6023
#
# Epoch 00001: val_loss improved from inf to 1.04618, saving model to best_model.h5
# Epoch 2/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.9915 - accuracy: 0.6302 - val_loss: 1.0077 - val_accuracy: 0.6277
#
# Epoch 00002: val_loss improved from 1.04618 to 1.00771, saving model to best_model.h5
# Epoch 3/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.8662 - accuracy: 0.6843 - val_loss: 1.0278 - val_accuracy: 0.6108
#
# Epoch 00003: val_loss did not improve from 1.00771
# Epoch 4/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.6248 - accuracy: 0.7852 - val_loss: 1.1919 - val_accuracy: 0.6032
#
# Epoch 00004: val_loss did not improve from 1.00771
# Epoch 5/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.3756 - accuracy: 0.8707 - val_loss: 1.4758 - val_accuracy: 0.5840
#
# Epoch 00005: val_loss did not improve from 1.00771
# Epoch 6/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.2392 - accuracy: 0.9211 - val_loss: 1.7579 - val_accuracy: 0.5663
#
# Epoch 00006: val_loss did not improve from 1.00771
# Epoch 7/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1536 - accuracy: 0.9513 - val_loss: 2.1466 - val_accuracy: 0.5761
#
# Epoch 00007: val_loss did not improve from 1.00771
# Epoch 8/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0994 - accuracy: 0.9688 - val_loss: 2.3916 - val_accuracy: 0.5847
#
# Epoch 00008: val_loss did not improve from 1.00771
# Epoch 9/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0741 - accuracy: 0.9776 - val_loss: 2.1625 - val_accuracy: 0.5753
#
# Epoch 00009: val_loss did not improve from 1.00771
# Epoch 10/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0555 - accuracy: 0.9824 - val_loss: 2.8005 - val_accuracy: 0.5793
#
# Epoch 00010: val_loss did not improve from 1.00771
# Epoch 11/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0489 - accuracy: 0.9852 - val_loss: 2.7127 - val_accuracy: 0.5775
#
# Epoch 00011: val_loss did not improve from 1.00771
# Epoch 12/50
# 1750/1750 [==============================] - 8s 4ms/step - loss: 0.0448 - accuracy: 0.9867 - val_loss: 2.8439 - val_accuracy: 0.5855
#
# Epoch 00012: val_loss did not improve from 1.00771
# Epoch 13/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0378 - accuracy: 0.9885 - val_loss: 2.8762 - val_accuracy: 0.5803
#
# Epoch 00013: val_loss did not improve from 1.00771
# Epoch 14/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0348 - accuracy: 0.9900 - val_loss: 2.7761 - val_accuracy: 0.5842
#
# Epoch 00014: val_loss did not improve from 1.00771
# Epoch 15/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0324 - accuracy: 0.9907 - val_loss: 3.9621 - val_accuracy: 0.5803
#
# Epoch 00015: val_loss did not improve from 1.00771
# Epoch 16/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0314 - accuracy: 0.9909 - val_loss: 3.4754 - val_accuracy: 0.5746
#
# Epoch 00016: val_loss did not improve from 1.00771
# Epoch 17/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0305 - accuracy: 0.9918 - val_loss: 2.6357 - val_accuracy: 0.5807
#
# Epoch 00017: val_loss did not improve from 1.00771
# Epoch 18/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0262 - accuracy: 0.9926 - val_loss: 3.1207 - val_accuracy: 0.5829
#
# Epoch 00018: val_loss did not improve from 1.00771
# Epoch 19/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0254 - accuracy: 0.9927 - val_loss: 3.6895 - val_accuracy: 0.5795
#
# Epoch 00019: val_loss did not improve from 1.00771
# Epoch 20/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0239 - accuracy: 0.9937 - val_loss: 4.0264 - val_accuracy: 0.5781
#
# Epoch 00020: val_loss did not improve from 1.00771
# Epoch 21/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0208 - accuracy: 0.9942 - val_loss: 3.4196 - val_accuracy: 0.5785
#
# Epoch 00021: val_loss did not improve from 1.00771
# Epoch 22/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0234 - accuracy: 0.9943 - val_loss: 3.1221 - val_accuracy: 0.5854
#
# Epoch 00022: val_loss did not improve from 1.00771
# Epoch 23/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0177 - accuracy: 0.9951 - val_loss: 4.0655 - val_accuracy: 0.5776
#
# Epoch 00023: val_loss did not improve from 1.00771
# Epoch 24/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0177 - accuracy: 0.9955 - val_loss: 3.3308 - val_accuracy: 0.5723
#
# Epoch 00024: val_loss did not improve from 1.00771
# Epoch 25/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0211 - accuracy: 0.9943 - val_loss: 3.4054 - val_accuracy: 0.5702
#
# Epoch 00025: val_loss did not improve from 1.00771
# Epoch 26/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0155 - accuracy: 0.9963 - val_loss: 4.1769 - val_accuracy: 0.5732
#
# Epoch 00026: val_loss did not improve from 1.00771
# Epoch 27/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0194 - accuracy: 0.9954 - val_loss: 3.4509 - val_accuracy: 0.5805
#
# Epoch 00027: val_loss did not improve from 1.00771
# Epoch 28/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0150 - accuracy: 0.9961 - val_loss: 4.2582 - val_accuracy: 0.5803
#
# Epoch 00028: val_loss did not improve from 1.00771
# Epoch 29/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0154 - accuracy: 0.9963 - val_loss: 3.5508 - val_accuracy: 0.5753
#
# Epoch 00029: val_loss did not improve from 1.00771
# Epoch 30/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0171 - accuracy: 0.9957 - val_loss: 3.1877 - val_accuracy: 0.5785
#
# Epoch 00030: val_loss did not improve from 1.00771
# Epoch 31/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0153 - accuracy: 0.9965 - val_loss: 3.4599 - val_accuracy: 0.5748
#
# Epoch 00031: val_loss did not improve from 1.00771
# Epoch 32/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0116 - accuracy: 0.9971 - val_loss: 4.7856 - val_accuracy: 0.5741
#
# Epoch 00032: val_loss did not improve from 1.00771
# Epoch 33/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0157 - accuracy: 0.9961 - val_loss: 4.6404 - val_accuracy: 0.5779
#
# Epoch 00033: val_loss did not improve from 1.00771
# Epoch 34/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0155 - accuracy: 0.9965 - val_loss: 3.4719 - val_accuracy: 0.5789
#
# Epoch 00034: val_loss did not improve from 1.00771
# Epoch 35/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0117 - accuracy: 0.9973 - val_loss: 3.9393 - val_accuracy: 0.5696
#
# Epoch 00035: val_loss did not improve from 1.00771
# Epoch 36/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0124 - accuracy: 0.9971 - val_loss: 4.2139 - val_accuracy: 0.5823
#
# Epoch 00036: val_loss did not improve from 1.00771
# Epoch 37/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0143 - accuracy: 0.9968 - val_loss: 3.9566 - val_accuracy: 0.5844
#
# Epoch 00037: val_loss did not improve from 1.00771
# Epoch 38/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0136 - accuracy: 0.9973 - val_loss: 3.0511 - val_accuracy: 0.5811
#
# Epoch 00038: val_loss did not improve from 1.00771
# Epoch 39/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0096 - accuracy: 0.9983 - val_loss: 3.7341 - val_accuracy: 0.5792
#
# Epoch 00039: val_loss did not improve from 1.00771
# Epoch 40/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0121 - accuracy: 0.9972 - val_loss: 4.3723 - val_accuracy: 0.5791
#
# Epoch 00040: val_loss did not improve from 1.00771
# Epoch 41/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0110 - accuracy: 0.9976 - val_loss: 3.6920 - val_accuracy: 0.5779
#
# Epoch 00041: val_loss did not improve from 1.00771
# Epoch 42/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0106 - accuracy: 0.9977 - val_loss: 4.9132 - val_accuracy: 0.5653
#
# Epoch 00042: val_loss did not improve from 1.00771
# Epoch 43/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0109 - accuracy: 0.9976 - val_loss: 3.5553 - val_accuracy: 0.5837
#
# Epoch 00043: val_loss did not improve from 1.00771
# Epoch 44/50
# 1750/1750 [==============================] - 8s 4ms/step - loss: 0.0137 - accuracy: 0.9974 - val_loss: 4.0686 - val_accuracy: 0.5751
#
# Epoch 00044: val_loss did not improve from 1.00771
# Epoch 45/50
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.0129 - accuracy: 0.9978 - val_loss: 3.8590 - val_accuracy: 0.5820
#
# Epoch 00045: val_loss did not improve from 1.00771
# Epoch 46/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 6.0868 - val_accuracy: 0.5800
#
# Epoch 00046: val_loss did not improve from 1.00771
# Epoch 47/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0117 - accuracy: 0.9984 - val_loss: 5.7717 - val_accuracy: 0.5759
#
# Epoch 00047: val_loss did not improve from 1.00771
# Epoch 48/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.0148 - accuracy: 0.9972 - val_loss: 4.2610 - val_accuracy: 0.5803
#
# Epoch 00048: val_loss did not improve from 1.00771
# Epoch 49/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0104 - accuracy: 0.9980 - val_loss: 5.5181 - val_accuracy: 0.5756
#
# Epoch 00049: val_loss did not improve from 1.00771
# Epoch 50/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.0164 - accuracy: 0.9974 - val_loss: 3.4246 - val_accuracy: 0.5846
#
# Epoch 00050: val_loss did not improve from 1.00771

# %%
ann.save_weights('stackoverflow_weights.h5')

# %%
# prediction = ann.predict(x_test)
score = ann.evaluate(xtest, ytest, verbose=0)
print("accuracy ANN", score[1] * 100)
# prediction = np.argmax(prediction, axis=1)
# y_test = np.argmax(y_test, axis=1)
# Out:
# accuracy ANN 58.45833420753479
